# %%
# https://github.com/azarijafari/E-commerce-Product-Classification/blob/main/Product%20Classification.ipynb

import pandas as pd
import lester as ld
import numpy as np

products = pd.read_csv(f"data/products-data-0.tsv", sep='\t', names=['product_id', 'product_category', 'product_name'])
reviews = pd.read_csv(f"data/reviews-0.tsv", sep='\t', names=['product_id', 'rating', 'review'])

products_with_reviews = products.merge(reviews, on='product_id')

# %%
from lester.messy.ecom_task3 import __featurise_original, __featurise_manual

original = __featurise_original(products_with_reviews.copy(deep=True))
manual = __featurise_manual(products_with_reviews.copy(deep=True))
# Out:
# [nltk_data] Downloading package wordnet to /Users/ssc/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/ssc/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /Users/ssc/projects/lester/lester/messy/ecom_task3.py:79: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
manual.shape
# Out:
# (500, 65)
